# %% [markdown]
# #Latex, letras griegas
#
# | Letra   | Código   | Resultado  |
# | ------- | -------- | ---------- |
# | alfa    | \\alpha  | $\alpha$  |
# | beta    | \\beta   | $\beta$   |
# | gamma   | \\gamma  | $\gamma$  |
# | delta   | \\delta  | $\delta$  |
# | epsilon | \\epsilon |$\epsilon$ |
# | theta   | \\theta  | $\theta$  |
# | lambda  | \\lambda | $\lambda$ |
# | mu      | \\mu     | $\mu$     |
# | pi      | \\pi     | $\pi$     |
# | sigma   | \\sigma  | $\sigma$  |
# | phi     | \\phi    | $\phi$    |
# | omega   | \\omega  | $\omega$  |
