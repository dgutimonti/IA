# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, iterations+1), train_acc_history, label='Train Accuracy', color='green', linewidth=2)
plt.plot(range(1, iterations+1), test_acc_history, label='Test Accuracy', color='orange', linewidth=2)
plt.title('Curva de Precisión (Accuracy) por Iteración', fontsize=14, fontweight='bold')
plt.xlabel('Iteraciones')
plt.ylabel('Accuracy')
plt.ylim(0.0, 1.0)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
## Curva de precisión (accuracy)
